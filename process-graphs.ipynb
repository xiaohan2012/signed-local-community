# %%
import pandas as pd
import networkx as nx
from helpers import parse_graph_in_csv

# %%
g = parse_graph_in_csv('graphs/congress/out.convote', verbose=False)
nx.write_gpickle(g, 'graphs/congress.pkl')

# %%
g = parse_graph_in_csv('graphs/cloister/out.moreno_sampson_sampson', verbose=True)
nx.write_gpickle(g, 'graphs/cloister.pkl')
# Out:
# conflicting sign for edge (15, 10), remove it
# conflicting sign for edge (4, 5), remove it
# conflicting sign for edge (15, 11), remove it
# conflicting sign for edge (10, 11), remove it
# conflicting sign for edge (5, 11), remove it
# conflicting sign for edge (16, 18), remove it
# conflicting sign for edge (9, 7), remove it
# conflicting sign for edge (10, 12), remove it
# conflicting sign for edge (6, 12), remove it
# conflicting sign for edge (1, 13), remove it
# conflicting sign for edge (10, 13), remove it
# conflicting sign for edge (5, 13), remove it
# conflicting sign for edge (12, 13), remove it
# conflicting sign for edge (1, 14), remove it
# conflicting sign for edge (3, 14), remove it
# conflicting sign for edge (12, 14), remove it
# conflicting sign for edge (1, 8), remove it
# conflicting sign for edge (3, 8), remove it
# conflicting sign for edge (5, 8), remove it

# %%
g = parse_graph_in_csv('graphs/epinions/soc-sign-epinions.txt', verbose=True, sep='\t')
nx.write_gpickle(g, 'graphs/epinions.pkl')
# Out:
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:2850: DtypeWarning: Columns (0,1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# conflicting sign for edge (79, 25), remove it
# conflicting sign for edge (199, 79), remove it
# conflicting sign for edge (203, 79), remove it
# conflicting sign for edge (205, 25), remove it
# conflicting sign for edge (270, 25), remove it
# conflicting sign for edge (321, 141), remove it
# conflicting sign for edge (424, 252), remove it
# conflicting sign for edge (450, 264), remove it
# conflicting sign for edge (578, 167), remove it
# conflicting sign for edge (578, 211), remove it
# conflicting sign for edge (578, 353), remove it
# conflicting sign for edge (578, 577), remove it
# conflicting sign for edge (640, 578), remove it
# conflicting sign for edge (655, 57), remove it
# conflicting sign for edge (655, 155), remove it
# ...

# %%
g.number_of_nodes(), g.number_of_edges()
# Out:
# (34, 125)

# %%
# process wiki-elect
g = nx.Graph()
with open('graphs/wiki-elect/wikiElec.ElecBs3.txt', 'r') as f:
    for l in f:
        if l.starts
